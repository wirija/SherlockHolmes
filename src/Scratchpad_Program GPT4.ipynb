# %%
# #!pip install chromadb
# %pip install -U langchain langchainhub openai --quiet

# Traceability - output might give different results

# %% [markdown]
# #  Initialise GenAI call

# %%
# GenAI Variables and models

import os

OPENAI_API_KEY = 'sk-xxx'
VERTEX_API_KEY = "xx"

OPENAI_MODEL_GPT4_0125 = 'gpt-4-0125-preview'
OPENAI_MODEL_VISION_PREVIEW = 'gpt-4-1106-vision-preview'
OPENAI_MODEL_GPT3 = 'gpt-3.5-turbo-0125'

VERTEX_MODEL_GEMINI = 'gemini-1.0-pro'
VERTEX_MODEL_GEMINI_VISION = 'gemini-1.0-pro-vision'

VERTEX_MODEL_ANTROPIC_HAIKU = 'claude-3-haiku@20240307'
VERTEX_MODEL_ANTROPIC_SONNET = 'claude-3-sonnet@20240229'
VERTEX_MODEL_MISTRAL = 'mistralai/Mixtral-8x7B-v0.1'
OPENAI_EMBEDDING_3_LARGE = 'text-embedding-3-large'
OPENAI_EMBEDDING_3_SMALL = 'text-embedding-3-small'
OPENAI_EMBEDDING_ADA_002 = 'text-embedding-ada-002'


os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
def list_file (dir:str, filter):
    return [os.path.join(root, file)  for root, dirs, files in os.walk(dir) for file in files if filter in file]

# %% [markdown]
# # Initilise ChromaDB

# %%
import chromadb
from chromadb.utils import embedding_functions
from chromadb.utils.embedding_functions import OpenAIEmbeddingFunction

embedding_fn = OpenAIEmbeddingFunction(api_key=os.environ.get('OPENAI_API_KEY'), model_name=OPENAI_EMBEDDING_ADA_002)
# embedding_fn = embedding_functions.DefaultEmbeddingFunction()

class Collections:
    Name: str
    Documents: list
    Metadatas: list
    Ids: list
    count_items: int

    def __init__ (self, Name, Documents, Metadatas, Ids):
        if ( 
            len(Documents) != len (Ids) &
            len(Metadatas) != len(Documents)
        ):
            raise Exception("Error: Length of parameters do not match")
        
        self.Name = Name
        self.Documents = Documents
        self.Metadatas = Metadatas
        self.Ids = Ids
        self.count_items = len(Ids)

    def get_count(self):return self.count_items
    def get_Documents(self): return self.Documents
    def get_Metadatas(self): return self.Metadatas
    def get_Ids(self): return self.Ids
    def get_Name(self): return self.Name


class Document_vdb:
    vdb: chromadb
    collections: Collections

    def __init__ (
            self, 
            vdb = None, 
            collections = None, 
            persistent_dir = None
        ):
        if vdb == None:
            if persistent_dir == None:
                self.vdb = chromadb.Client()
            else:
                self.vdb = chromadb.PersistentClient(path = persistent_dir)
        else:
            self.vdb = vdb
        
        if collections != None:
            self.set_collections(collections)
        else: self.collections = None

    def get_vdb (self):
        return self.vdb
    
    def get_collection(
            self, 
            collection_name:str
        ):
        return self.vdb.get_collection(name = collection_name )

    def set_collections(
            self, 
            collections:Collections, 
            emb_fn = None
        ):

        if emb_fn == None: emb_fn = embedding_fn
        count_items = collections.get_count()

        collection = self.vdb.get_or_create_collection(
            name=collections.get_Name(), 
            embedding_function=emb_fn 
        )
        
        Documents = collections.get_Documents()
        Metadatas = collections.get_Metadatas()
        Ids = collections.get_Ids()

        for i in range(0, count_items):
            collection.add( 
                documents = Documents[i],
                metadatas = Metadatas[i],
                ids = Ids[i]
            )

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter, TokenTextSplitter
import hashlib
import uuid 
import pypdf


text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=2000,
    chunk_overlap=0,
    length_function=len,
    is_separator_regex=False,
)

text_splitter_token = TokenTextSplitter(chunk_size=500, chunk_overlap=0)

def create_collections_dir (dir, collection_name) -> Collections:
    files = list_file(dir, ".pdf")
    Metadatas = []
    Ids = []
    Documents = []

    for file in files:
        with open(file, 'rb') as f:
            hash = str(hashlib.md5(f.read()).hexdigest())

        pdfFileObject = open(file, 'rb')
        pdfReader = pypdf.PdfReader(pdfFileObject)
        count = len(pdfReader.pages)

        for i in range(count):
            metadata = {
                'source': file,
                'page': i,
                'source_hash': hash,
            }
            page_chunks = text_splitter.split_text (pdfReader.pages[i].extract_text())
            for page_chunk in page_chunks:
                Ids.append(uuid.uuid1().hex)
                Documents.append(page_chunk)
                Metadatas.append(metadata)

    return Collections(
        Name = collection_name ,
        Documents=Documents,
        Metadatas=Metadatas,
        Ids=Ids
    )


def create_collection_token (file, collection_name) -> Collections:
    Metadatas = []
    Ids = []
    Documents = []

    with open(file, 'rb') as f:
        hash = str(hashlib.md5(f.read()).hexdigest())

    pdfFileObject = open(file, 'rb')
    pdfReader = pypdf.PdfReader(pdfFileObject)
    count = len(pdfReader.pages)

    for i in range(count):
        metadata = {
            'source': file,
            'page': i,
            'source_hash': hash,
        }
        page_chunks = text_splitter_token.split_text (pdfReader.pages[i].extract_text())
        for page_chunk in page_chunks:
            Ids.append(uuid.uuid1().hex)
            Documents.append(page_chunk)
            Metadatas.append(metadata)

    return Collections(
        Name = collection_name ,
        Documents=Documents,
        Metadatas=Metadatas,
        Ids=Ids
    )



def create_collection_char (file, collection_name) -> Collections:
    Metadatas = []
    Ids = []
    Documents = []

    with open(file, 'rb') as f:
        hash = str(hashlib.md5(f.read()).hexdigest())

    pdfFileObject = open(file, 'rb')
    pdfReader = pypdf.PdfReader(pdfFileObject)
    count = len(pdfReader.pages)

    for i in range(count):
        metadata = {
            'source': file,
            'page': i,
            'source_hash': hash,
        }
        page_chunks = text_splitter.split_text (pdfReader.pages[i].extract_text())
        for page_chunk in page_chunks:
            Ids.append(uuid.uuid1().hex)
            Documents.append(page_chunk)
            Metadatas.append(metadata)

    return Collections(
        Name = collection_name ,
        Documents=Documents,
        Metadatas=Metadatas,
        Ids=Ids
    )

# %%
# from langchain.embeddings import OpenAIEmbeddings


# dir = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling'
# persist_dir = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling/chromadb_THL_pages_token'
# collection_name = "Tan_Hooi_Ling"
# files = list_file( dir, ".pdf")
# no_files = len(files)
# i = 1

# for file in files:
#     print (f"===== Processing file {i} / {no_files} -- {file}")
#     FS_collection  = create_collection_token(file, collection_name=f"{collection_name}_{i}")
#     test = Document_vdb(collections= FS_collection, persistent_dir= persist_dir)
#     i = i + 1

# %%
# from langchain.embeddings import OpenAIEmbeddings


# dir = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling'
# persist_dir_char = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling/chromadb_THL_pages_char'
# collection_name = "Tan_Hooi_Ling"
# files = list_file( dir, ".pdf")
# no_files = len(files)
# i = 1

# for file in files:
#     print (f"===== Processing file {i} / {no_files} -- {file}")
#     FS_collection  = create_collection_char(file, collection_name=f"{collection_name}_{i}")
#     test = Document_vdb(collections= FS_collection, persistent_dir= persist_dir_char)
#     i = i + 1

# %% [markdown]
# # Summarising Tan Hooi Ling

# %%
persist_dir_char = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling/chromadb_THL_pages_char'
persist_dir_token = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling/chromadb_THL_pages_token'

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI
from langchain.retrievers.multi_query import MultiQueryRetriever


# OpenAIEmbeddings = OpenAIEmbeddings(api_key=os.environ.get('OPENAI_API_KEY'), model_name=OPENAI_EMBEDDING_ADA_002)
persist_dir = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling/chromadb_THL_pages_token'


llm = ChatOpenAI(model_name=OPENAI_MODEL_GPT4_0125, temperature=0)

client = chromadb.PersistentClient(path=persist_dir_char)  # or HttpClient()
collections = client.list_collections()
llm_results = []
customer_name = "Tan Hooi Ling"

for collection in collections:
    print (collection.name)


    vectordb = Chroma(persist_directory=persist_dir, collection_name = collection.name, embedding_function=OpenAIEmbeddings())

    retriever = vectordb.as_retriever( search_type="mmr" , search_kwargs={"k": 5, "include_metadata": True})




    retriever_from_llm = MultiQueryRetriever.from_llm( retriever=retriever, llm=llm)


    question = """

        Assume the role of a research assistant researching the biography of a person. Your current target is {customer_name}.
        You are to review the content in the text below. 

        Task: Review a document about {customer_name} and identify key biographical facts:

        1) Early Life:
            1a) Birthplace & Date
            1b) Hometown
            1c) Siblings (number)
        2) Education:
            2a) Schools attended (names & locations)
            2b) Degrees/Courses studied
            2c) Dates of attendance
        3) Career:
            3a) Employers & Positions
            3b) Employment Dates (start date and end date)


        Output:
         - Output will be markdown format.
         - Each of the 3 section will be a # Heading level 1
         - Refer to the output template in markdown format below

        <Output Template> 
        # Summary of {customer_name}
        <Place the summary of {Customer_Name} here>

        # Early Life       
        <place the {Customer_Name} early Life here in text>

        # Education 
        Output the Education background result in the following markdown format
        | School Name | Location | Course name | Degree type | Start Year | Graduation Year |
        |---|---|---|---|---|---|
        
        # Career 
        Output the career result in the following markdown format
        | Employer Name | Location | Job title | Start Year | End Year |
        |---|---|---|---|---|

        End year = refers to when the person is no longer part of the company


        contrainst:    
            Where you are unable to find the information, state them as "Not Available"
        """
    qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

    # unique_docs = retriever_from_llm.from_llm(query=question)
    result = qa_chain({"query": question})

    llm_results.append (result['result'])

    print ("================ END OF COLLECTION 1 =================")
# Out:
# Tan_Hooi_Ling_4
# /Users/peterwirija/Documents/GenAI/.venv/lib/python3.8/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Number of requested results 20 is greater than number of elements in index 8, updating n_results = 8
# ================ END OF COLLECTION 1 =================
# Tan_Hooi_Ling_5
# Number of requested results 20 is greater than number of elements in index 2, updating n_results = 2
# ================ END OF COLLECTION 1 =================
# Tan_Hooi_Ling_2
# ================ END OF COLLECTION 1 =================
# Tan_Hooi_Ling_1
# Number of requested results 20 is greater than number of elements in index 3, updating n_results = 3
# ================ END OF COLLECTION 1 =================
# Tan_Hooi_Ling_3
# Number of requested results 20 is greater than number of elements in index 4, updating n_results = 4
# ================ END OF COLLECTION 1 =================
# Tan_Hooi_Ling_6
# ================ END OF COLLECTION 1 =================

# %%
combined_results = "\n\n\n".join ([text for text in llm_results])


prompt_combine_result= rf"""
    You are summarising a set of result from LLM retrieval. The topic is the biography you like to write include {customer_name} early Life, Education, and Career
    Each result of the LLM is separated by three blank lines (\n\n\n).
    The documents were originally formatted in Markdown.and structured in the following manner 
    
    <RESULT STRUCTURE> 
    # Summary of document
    Place the summary of the document here
    
    # Summary of {customer_name}
    <Place a comprehensive summary of {customer_name} here>

    # Early Life       
    <place the {customer_name} early Life here in text>

    # Education 
    Output the Education background result in the following markdown format
    | School Name | Location | Course name | Degree type | Start Year | Graduation Year |
    |---|---|---|---|---|---|
    
    # Career 
    Output the career result in the following markdown format
    | Employer Name | Location | Job title | Start Year | End Year |
    |---|---|---|---|---|
    
    Sort the table by Employer Name

    The following contraints are only for Start Year and End Year Columns:
    - Start Year = Year of start of employment. Only output Start year without month or day. Where Start Year is not available output a 0. Where Start Year is "present" or "current", replace it with the current year
    - End Year = Year of end of employment. Only output End year without month or day. Where End Year is not available output 0. Where End Year is "present" or "current", Replace it with the current year


    Task: 
    review the text between <RESULTS> and <\RESULTS>. 
    Combine the information for each section 
        - # Summary of {customer_name}
        - # Early Life  
        - # Education 
        - # Career 

    <RESULTS>
     {combined_results}
    <\RESULTS>

    contrainst:
        Ensure that # Summary of {customer_name} is comprehensive
        The output should retain the same structure in each section
        Do not review results that are "No information found!!"
        Do not include <RESULTS> or <\RESULTS> in the output
        Start year and End Year should only have Year (YYYY) without month or day
"""

result_summary = llm.invoke(prompt_combine_result)

# %%
print (result_summary.content)
# Out:
# # Summary of Tan Hooi Ling
#
# Tan Hooi Ling is a prominent figure in the tech industry, best known as the co-founder of Grab, a leading ride-hailing platform in Southeast Asia. Born and raised in Kuala Lumpur, Malaysia, in a middle-class family, she has demonstrated remarkable dedication and strategic thinking throughout her career. Tan Hooi Ling holds a Bachelor's degree in Mechanical Engineering from the University of Bath and an MBA from Harvard Business School. Before co-founding Grab, she gained significant experience at Eli Lilly, McKinsey & Company, and Salesforce. Despite stepping down from operational roles and the board by the end of 2023, she continues to serve as an adviser to Grab. Tan Hooi Ling is also known for her contributions to the board of Wise (formerly TransferWise) and is celebrated for her commitment to improving lives through technology, her strategic role in Grab's growth, and her passion for adventure and personal growth.
#
# # Early Life
#
# Tan Hooi Ling was born and raised in Kuala Lumpur, Malaysia, in a middle-class Malaysian Chinese household. Her father is a civil engineer, and her mother is a remisier. She has an older brother who is a software programmer currently living in New Zealand. During her childhood in Petaling Jaya, she attended state schools, was actively involved in sports like badminton, and pursued music, achieving a diploma in piano and Grade 8 in violin.
#
# # Education
#
# | School Name | Location | Course name | Degree type | Start Year | Graduation Year |
# |---|---|---|---|---|---|
# | University of Bath | Britain/United Kingdom | Mechanical Engineering | Bachelor's Degree/Bachelor of Engineering | Not Available | 2006 |
# | Harvard Business School (HBS) | United States | Business Administration, Business at the Base of the Pyramid, Launching Technology Ventures | MBA | 2011 | 2011 |
#
# # Career
#
# | Employer Name | Location | Job title | Start Year | End Year |
# |---|---|---|---|---|
# | Eli Lilly | Basingstoke, Britain/UK | Industrial Placement | 0 | 0 |
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012 | 2023 |
# | McKinsey & Company | Malaysia/Various (Southeast Asia, North America, Latin America, Australia) | Management Consultant, Business Analyst, Associate | 2006 | 2013 |
# | Salesforce | San Francisco, USA | Not Available | 2013 | 2015 |
# | Wise (formerly TransferWise) | Not Available | Board Member | 0 | 0 |
#
# Tan Hooi Ling's career journey showcases her progression from roles in industrial placement and consulting to leadership positions at Grab, where she significantly contributed to the company's success. Her experience spans across various countries and industries, underlining her versatile skill set and strategic vision.

# %%
import re
import pandas as pd
def MD_to_df (text):
    lines = text.strip().split("\n")
    header = lines[0].strip("|").split("|")
    print (header)
    data = [] 

    # Loop through lines starting from 2
    for line in lines[3:]:
        print (line)
        # Break once we hit an empty line
        if not line.strip():
            break
            
        cols = line.strip("|").split("|")
        row = dict(zip(header, cols))
        data.append(row)
        
    return pd.DataFrame(data)

# %%
import pandas as pd


result_string = str(result_summary.content)
results_content = result_string[result_string.find("# Career") + 8:]

employment_history =  MD_to_df (results_content)


print (employment_history)
employment_history[' Start Year '] = employment_history[' Start Year '].astype(int)
employment_history[' End Year '] = employment_history[' End Year '].astype(int) 

employment_history = employment_history.astype({' Start Year ':'int64', ' End Year ':'int64'})

for i, years in employment_history.apply(
    lambda x: range(
        min(x[' Start Year '], x[' End Year ']),
        max(x[' Start Year '], x[' End Year ']) + 1
    ),
    axis='columns'
).items():
    for year in years:
        new_index = len(employment_history.index)
        employment_history.loc[new_index] = employment_history.loc[i].values
        employment_history.loc[new_index, 'year'] = int(year)

employment_history.dropna(inplace = True)
employment_history.reset_index()

# employment_history.loc[(employment_history[' Start Year '] == 0) & (employment_history[' End Year '] != 0) & (employment_history['year'] != 0) ]
employment_history.drop(employment_history.loc[(employment_history[' Start Year '] == 0) & (employment_history[' End Year '] != 0) & (employment_history['year'] != 0) ].index, inplace=True)
employment_history.drop(employment_history.loc[(employment_history[' Start Year '] != 0) & (employment_history[' End Year '] == 0) & (employment_history['year'] != 0) ].index, inplace=True)

employment_history
# Out:
# [' Employer Name ', ' Location ', ' Job title ', ' Start Year ', ' End Year ']
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012 | 2023 |
# | McKinsey & Company | Malaysia/Various (Southeast Asia, North America, Latin America, Australia) | Management Consultant, Business Analyst, Associate | 2006 | 2013 |
# | Salesforce | San Francisco, USA | Not Available | 2013 | 2015 |
# | Wise (formerly TransferWise) | Not Available | Board Member | 0 | 0 |
#
#                    Employer Name   \
# 0                           Grab
# 1             McKinsey & Company
# 2                     Salesforce
# 3   Wise (formerly TransferWise)
#
#                                            Location   \
# 0       Kuala Lumpur, Malaysia & Regional/Singapore
# 1   Malaysia/Various (Southeast Asia, North Ameri...
# 2                                San Francisco, USA
# 3                                     Not Available
#
#                                           Job title   Start Year   End Year
# 0   Co-founder, COO, Chief Operating Officer, Tec...        2012       2023
# 1   Management Consultant, Business Analyst, Asso...        2006       2013
# 2                                     Not Available         2013       2015
# 3                                      Board Member            0          0
#                     Employer Name   \
# 4                            Grab
# 5                            Grab
# 6                            Grab
# 7                            Grab
# 8                            Grab
# 9                            Grab
# 10                           Grab
# 11                           Grab
# 12                           Grab
# 13                           Grab
# 14                           Grab
# 15                           Grab
# 16             McKinsey & Company
# 17             McKinsey & Company
# 18             McKinsey & Company
# 19             McKinsey & Company
# 20             McKinsey & Company
# 21             McKinsey & Company
# 22             McKinsey & Company
# 23             McKinsey & Company
# 24                     Salesforce
# 25                     Salesforce
# 26                     Salesforce
# 27   Wise (formerly TransferWise)
#
#                                             Location   \
# 4        Kuala Lumpur, Malaysia & Regional/Singapore
# 5        Kuala Lumpur, Malaysia & Regional/Singapore
# 6        Kuala Lumpur, Malaysia & Regional/Singapore
# 7        Kuala Lumpur, Malaysia & Regional/Singapore
# 8        Kuala Lumpur, Malaysia & Regional/Singapore
# 9        Kuala Lumpur, Malaysia & Regional/Singapore
# 10       Kuala Lumpur, Malaysia & Regional/Singapore
# 11       Kuala Lumpur, Malaysia & Regional/Singapore
# 12       Kuala Lumpur, Malaysia & Regional/Singapore
# 13       Kuala Lumpur, Malaysia & Regional/Singapore
# 14       Kuala Lumpur, Malaysia & Regional/Singapore
# 15       Kuala Lumpur, Malaysia & Regional/Singapore
# 16   Malaysia/Various (Southeast Asia, North Ameri...
# 17   Malaysia/Various (Southeast Asia, North Ameri...
# 18   Malaysia/Various (Southeast Asia, North Ameri...
# 19   Malaysia/Various (Southeast Asia, North Ameri...
# 20   Malaysia/Various (Southeast Asia, North Ameri...
# 21   Malaysia/Various (Southeast Asia, North Ameri...
# 22   Malaysia/Various (Southeast Asia, North Ameri...
# 23   Malaysia/Various (Southeast Asia, North Ameri...
# 24                                San Francisco, USA
# 25                                San Francisco, USA
# 26                                San Francisco, USA
# 27                                     Not Available
#
#                                            Job title    Start Year   \
# 4    Co-founder, COO, Chief Operating Officer, Tec...          2012
# 5    Co-founder, COO, Chief Operating Officer, Tec...          2012
# 6    Co-founder, COO, Chief Operating Officer, Tec...          2012
# 7    Co-founder, COO, Chief Operating Officer, Tec...          2012
# 8    Co-founder, COO, Chief Operating Officer, Tec...          2012
# 9    Co-founder, COO, Chief Operating Officer, Tec...          2012
# 10   Co-founder, COO, Chief Operating Officer, Tec...          2012
# 11   Co-founder, COO, Chief Operating Officer, Tec...          2012
# 12   Co-founder, COO, Chief Operating Officer, Tec...          2012
# 13   Co-founder, COO, Chief Operating Officer, Tec...          2012
# 14   Co-founder, COO, Chief Operating Officer, Tec...          2012
# 15   Co-founder, COO, Chief Operating Officer, Tec...          2012
# 16   Management Consultant, Business Analyst, Asso...          2006
# 17   Management Consultant, Business Analyst, Asso...          2006
# 18   Management Consultant, Business Analyst, Asso...          2006
# 19   Management Consultant, Business Analyst, Asso...          2006
# 20   Management Consultant, Business Analyst, Asso...          2006
# 21   Management Consultant, Business Analyst, Asso...          2006
# 22   Management Consultant, Business Analyst, Asso...          2006
# 23   Management Consultant, Business Analyst, Asso...          2006
# 24                                     Not Available           2013
# 25                                     Not Available           2013
# 26                                     Not Available           2013
# 27                                      Board Member              0
#
#      End Year     year
# 4         2023  2012.0
# 5         2023  2013.0
# 6         2023  2014.0
# 7         2023  2015.0
# 8         2023  2016.0
# 9         2023  2017.0
# 10        2023  2018.0
# 11        2023  2019.0
# 12        2023  2020.0
# 13        2023  2021.0
# 14        2023  2022.0
# 15        2023  2023.0
# 16        2013  2006.0
# 17        2013  2007.0
# 18        2013  2008.0
# 19        2013  2009.0
# 20        2013  2010.0
# 21        2013  2011.0
# 22        2013  2012.0
# 23        2013  2013.0
# 24        2015  2013.0
# 25        2015  2014.0
# 26        2015  2015.0
# 27           0     0.0

# %%
persist_dir = r'/Users/peterwirija/Documents/GenAI/Data/Tan_Hooi_Ling/chromadb_THL_pages_token'

llm = ChatOpenAI(model_name=OPENAI_MODEL_GPT4_0125, temperature=0)

client = chromadb.PersistentClient(path=persist_dir_char)  # or HttpClient()
collections = client.list_collections()
llm_results = []
combined_result = []

for i in range(0, len(employment_history)):
    for collection in collections:
        # text = "\n\n\n".join ([item for item in collection.get()['documents'] if "hooi ling".lower() in item.lower()])


        for text in collection.get()['documents']:
            if not("hooi ling".lower() in text.lower()): continue
            prompt_employment_SOW= rf"""
                You are an analyst. Your job is to review the text between <START OF TEXT> and <END OF TEXT> below to identify  {customer_name}'s income.
                Income is defined as any salary, shares, bonuses, and benefits. 

                {customer_name} has multiple employment. You are to gather information about a specific employment
                    Employer: {employment_history.iloc[i,0]}
                    Location: {employment_history.iloc[i,1]}
                    Job Title: {employment_history.iloc[i,2]}
                    Year of employment : {employment_history.iloc[i,5]}

                <START OF TEXT>
                {text}
                <END OF TEXT>

                Task: 
                    Review the between <START OF TEXT> and <END OF TEXT>
                    Extract key income information that {customer_name} received during {customer_name} time in {employment_history.iloc[i,0]} for the year {employment_history.iloc[i,5]}. information should include
                    - Salary
                    - Shares
                    - Bonuses
                    - Other benefits
                    Provide a narrative to {customer_name} employment in {employment_history.iloc[i,0]}

                Output:
                    Put the output in markdown format as per the following table:
                    | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment  | Narrative |

                    Markdown table Data dictionary:
                    Employer Name =  Employer name
                    Location =  location employer is located at
                    Job Title = Job title at place of employment 
                    Year = Current Year under review
                    Salary from employment  = Salary {customer_name} received for the year that {customer_name} was employed by employer
                    Bonus from Employment = Bonus  {customer_name} received for the year that {customer_name} was employed by employer
                    Shares = Shares  {customer_name} held in the company for the year
                    Benefit from Employment = Benefits, other than Salary, Bonus and shares, receiverd by {customer_name} for the year that {customer_name} was employed by employer

                contrainst:
                    Ensure that Narrative column is comprehensive
                    Do not make up information.
                    Where information is not available state "Not Available"
            """

            result = llm.invoke(prompt_employment_SOW)
            # qa_chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)

            # # unique_docs = retriever_from_llm.from_llm(query=question)
            # result = qa_chain({"query": prompt_employment_SOW})
            combined_result.append (result.content)

            print (rf"============== {i} ===============")
            print (result.content)

combined_result
# Out:
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling co-founded Grab in 2012 alongside fellow Malaysian Anthony Tan. Despite the text providing insights into her role and the early days of Grab, specific income details such as salary, bonuses, shares, and other benefits for the year 2012 are not disclosed. The narrative focuses on her humble beginnings and the choice of a low-key lifestyle despite her significant achievements. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling, co-founder of Grab, has played a pivotal role in the company's growth and expansion since its inception in 2012. Despite Grab's significant achievements, including expanding to 65 cities in seven countries and attracting over US$1 billion in funding, specific details regarding Tan Hooi Ling's income, including salary, bonuses, shares, and other benefits for the year 2012, are not provided in the text. Tan Hooi Ling prefers to stay behind the scenes, focusing on operational and technological advancements within Grab. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provides a glimpse into Tan Hooi Ling's character and her role at Grab, highlighting her humble beginnings, dedication, and the innovative approach she brought to the company. However, it does not disclose specific income details such as salary, bonuses, shares, or other benefits received during her time at Grab in 2012. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, bonuses, shares, or other benefits received during her employment at Grab in the year 2012. Tan Hooi Ling's narrative in the text focuses on her personal background and her relationship with her family, without disclosing any financial or employment-related details specific to her role at Grab. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, shares, bonuses, or other benefits from her employment at Grab in the year 2012. Tan Hooi Ling's narrative focuses on her educational background, her early career decisions, and the pivotal moment of meeting Anthony Tan at Harvard Business School, which eventually led to her co-founding Grab. However, details regarding her compensation at Grab are not disclosed in the text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling co-founded Grab in Kuala Lumpur after graduating from Harvard Business School. Initially known as MyTeksi, the company was started with a small team with the idea of making taxi rides safer in Kuala Lumpur. This idea was conceived during her time at HBS and further developed into a business plan that was a runner-up in a contest held by HBS. Despite taking a six-month leave from McKinsey to launch Grab, and then returning to work at Salesforce, she maintained constant contact with the Grab team before joining full-time in April 2015. Her roles at Grab have included overseeing people operations and technology. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab for the year 2012. It discusses the challenges and experiences faced by Grab and Tan Hooi Ling's role in the company's growth and operations, highlighting the importance of adaptation and practical implementation of ideas in a rapidly evolving business environment. However, it lacks detailed financial or compensation-related details. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income from her employment at Grab in the year 2012. It mentions her role and contributions to the company but does not detail her salary, bonuses, shares, or other benefits received. Tan Hooi Ling's personal approach to her net worth and lifestyle choices are briefly touched upon, indicating a focus on the company's success and impact rather than personal financial gain. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|-----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling co-founded Grab in 2012 and has played a pivotal role in its development, holding various operational and technology leadership positions. Despite the detailed account of her contributions and roles within Grab, the text does not provide specific information regarding her salary, bonuses, shares, or other benefits received during her tenure in 2012. Her commitment and leadership have been instrumental in Grab's growth, although specific income details for the year 2012 are not disclosed in the provided text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab for the year 2012. Tan Hooi Ling's roles and contributions to Grab are acknowledged, but financial compensation details are not disclosed in the text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The provided text does not contain specific information regarding Tan Hooi Ling's salary, bonuses, shares, or other benefits received from employment at Grab for the year 2012. It mentions Tan Hooi Ling's involvement with a Malaysian local partner, Green Aurora Sdn Bhd, through ownership in Jaya Grocer, indicating a business relationship outside of direct compensation from Grab. However, details on income from this involvement or direct compensation from Grab are not provided. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income from her employment at Grab for the year 2012. It mentions her involvement with Jaya Grocer Holdings Sdn. Bhd. through a local partner entity, indicating her business activities outside of Grab. However, details such as salary, bonuses, shares, or other benefits from her role at Grab are not disclosed in the text. |
# ============== 0 ===============
# ```markdown
# | Employer Name | Location                                  | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                   |
# |---------------|-------------------------------------------|-----------|------|------------------------|-----------------------|--------|-----------------------------------|--------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder | 2012 | Not Available          | Not Available         | Not Available | Not Available                     | The text provided does not contain specific income information for Tan Hooi Ling for the year 2012. Tan Hooi Ling is listed as a Founder and Director at Grab, indicating a significant role in the company's leadership but without details on salary, shares, bonuses, or other benefits received. |
# ```
# ============== 0 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|---------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012 | Not Available          | Not Available         | Not Available | Not Available                       | Tan Hooi Ling, after graduating from Harvard Business School in mid-2011, co-founded Grab and was instrumental in its incorporation and launch by the end of 2011. Although she took a brief hiatus to work at Salesforce and as a consultant at McKinsey & Company, there is no specific income information available for her tenure at Grab in the year 2012. |
# ```
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling's specific income details for the year 2012 while employed at Grab, including salary, bonuses, shares, and other benefits, are not provided in the text. The text does mention Tan Hooi Ling holding less than 1% of the outstanding Ordinary Shares with options, restricted shares, and RSUs granted at various dates from 2019 to 2022, but does not detail income for the year 2012. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | 29,723,020 Class A Ordinary Shares | Not Available | Tan Hooi Ling, as a co-founder and holding various operational and technology leadership roles at Grab since 2012, has significantly contributed to the company's growth and expansion across the region. The text provides specific information on Tan Hooi Ling's shareholding in Grab, indicating a beneficial ownership of 29,723,020 Class A Ordinary Shares as of February 28, 2023. However, details regarding Tan Hooi Ling's salary, bonuses, and other benefits from employment at Grab for the year 2012 are not provided in the text. Therefore, while we can ascertain Tan Hooi Ling's investment in the company through share ownership, other aspects of income from Grab remain undisclosed. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's salary, bonuses, shares, or other benefits received during the year 2012 while employed at Grab. It mentions a lock-up agreement extension for shares held by key executives, including Tan Hooi Ling, but does not detail the income derived from these shares or any other form of compensation. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The provided text does not contain specific information regarding Tan Hooi Ling's income, salary, bonuses, shares, or other benefits from her employment at Grab for the year 2012. The text primarily discusses contracts and shareholdings related to Grab's business activities, without detailing individual compensation packages. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The provided text does not contain specific information regarding Tan Hooi Ling's income, salary, bonuses, shares, or other benefits from her employment at Grab for the year 2012. It mentions her involvement in a separate entity related to Jaya Grocer and a transaction involving MCars Sdn. Bhd., but does not detail her compensation from Grab. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The provided text outlines various services and offerings by Grab, such as GrabMart, GrabSupermarket, and GrabPay, among others. It also mentions key executives, including Tan Hooi Ling as co-founder. However, specific details regarding Tan Hooi Ling's income, including salary, bonuses, shares, and other benefits from her employment at Grab in the year 2012, are not provided in the text. Therefore, this information is not available based on the given text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not specify Tan Hooi Ling's salary, bonuses, specific shares, or other benefits received during the year 2012 while employed at Grab. It mentions lock-up agreements and eligibility for resale of shares for key executives, including Tan Hooi Ling, but does not detail the income or benefits derived from these shares or any other form of compensation for the year under review. |
# ============== 0 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|----------------------------------|-----------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012 | Not Available          | Not Available         | Not Available | Not Available                    | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, shares, bonuses, or other benefits from her employment at Grab in the year 2012. Tan Hooi Ling, as a co-founder and holding various operational and technology leadership roles, has been instrumental in setting the vision and cultural foundations for Grab. However, details on her compensation for the year 2012 are not disclosed in the text. |
# ```
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling co-founded Grab with Anthony Tan in 2012 and has played a pivotal role in its growth and expansion across Southeast Asia. Despite her various operational and technology leadership roles, including COO, the specific details regarding her salary, bonuses, shares, and other benefits during her tenure in 2012 are not provided in the text. Tan's commitment to Grab and her leadership in technology and operations have been instrumental in the company's success, reflecting her significant contribution to the organization. However, the text does not disclose financial compensation details. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling, as a co-founder and key operational and technology leader at Grab since 2012, has played a significant role in the company's growth and expansion across Southeast Asia. Despite the detailed review of the provided text, specific income details such as salary, bonuses, shares, and other benefits for the year 2012 are not mentioned. Therefore, this information is not available from the text provided. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling co-founded Grab and served in various operational and technology leadership roles including COO. Despite the detailed career history provided, specific income details such as salary, bonuses, shares, and other benefits for the year 2012 are not available in the text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provides a background on Tan Hooi Ling's career path and her involvement in the founding of Grab. It details her inspiration for Grab and her role in its creation while studying at Harvard Business School. However, it does not provide specific information regarding her income, including salary, bonuses, shares, or other benefits from her employment at Grab in the year 2012. |
# ============== 0 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|----------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012 | Not Available          | Not Available         | Not Available | Not Available                    | Tan Hooi Ling co-founded Grab in 2012, initially launching the mobile application MyTeksi. Despite starting the company, she had to return to McKinsey to fulfill a bond obligation, only returning to Grab full-time in 2015 as COO. During her tenure, she focused on product, human resources, and customer experience. Specific income details for 2012 are not provided in the text. |
# ```
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The provided text does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab for the year 2012. Tan Hooi Ling is recognized for her significant role in co-founding Grab and steering the company into new markets, as well as her various operational and technology leadership roles within the company. However, detailed financial compensation details for the year 2012 are not disclosed in the text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling, as a co-founder and key executive at Grab, played significant roles in various operational and technology leadership capacities since the company's early days in 2012. Despite the detailed overview of Grab's operations and ventures, the text does not provide specific information regarding Tan Hooi Ling's salary, bonuses, shares, or other benefits received during her tenure at Grab. It is noted that Tan Hooi Ling no longer holds any position at Grab, indicating her departure from the company. However, the exact details of her income or compensation during her time at Grab are not disclosed in the provided text. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's salary, bonuses, shares, or other benefits received during the year 2012 while employed at Grab. It mentions shares becoming eligible for resale at later dates and involves key executives, including Tan Hooi Ling, but does not detail income from 2012. |
# ============== 0 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares            | Benefit received from Employment | Narrative                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|-------------------|---------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012 | Not Available          | Not Available         | 22,907,952 Class B | Not Available                   | Tan Hooi Ling, in her multifaceted roles at Grab since 2012, has been instrumental in the operational and technological advancements of the company. The text reveals her significant shareholding, with 22,907,952 Class B Ordinary Shares directly held and an additional 7,243,301 Class B Ordinary Shares potentially acquirable within 60 days through options or vesting of restricted share units under Grab's share incentive plans. However, specific details regarding her salary, bonuses, and other benefits for the year 2012 are not provided. |
# ```
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's salary, bonuses, shares, or other benefits received during the year 2012 while employed at Grab. The text mainly discusses the lock-up agreements related to shares for key executives, including Tan Hooi Ling, without detailing the exact income or benefits derived from such agreements. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab for the year 2012. Tan Hooi Ling's roles and contributions at Grab are acknowledged, but the document focuses on financial transactions and agreements involving the company rather than individual compensation details. |
# ============== 0 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2012.0 | Not Available | Not Available | Not Available | Not Available | The provided text does not contain specific information regarding Tan Hooi Ling's salary, bonuses, shares, or other benefits received during her tenure at Grab for the year 2012. It mentions her involvement with Grab and a subsequent venture, indicating her active role in the company's operations and strategic decisions, but does not detail her income from Grab. |
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO | 2013.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling, at the age of 33, held the positions of co-founder and chief operating officer at Grab, a company she co-founded in 2012 with fellow Malaysian Anthony Tan. The text does not provide specific details regarding her income, including salary, bonuses, shares, or other benefits from her employment at Grab for the year 2013. Tan Hooi Ling's choice of a modest and grounded lifestyle is highlighted, but financial details related to her role at Grab are not disclosed in the provided text. |
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|-----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling, as a co-founder and key operational and technology leader at Grab since 2013, has played a significant role in the company's growth and expansion. Despite the detailed insights into Grab's business operations, funding, and valuation provided in the text, specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, and other benefits from her employment at Grab for the year 2013, is not available in the provided text. The narrative focuses on the company's journey, its operational scope, and Tan Hooi Ling's personal approach to her role and media interaction, without disclosing financial compensation details.
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab in the year 2013. Tan Hooi Ling, as a co-founder and holding various operational and technology leadership roles at Grab, has been instrumental in the company's early efforts to expand and secure partners, as illustrated by her active involvement in outreach activities. However, the text focuses more on her personal attributes, work ethic, and contributions to Grab's mission rather than financial compensation details. |
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, bonuses, shares, or other benefits received during her employment at Grab in the year 2013. It focuses on her personal background and her journey, without detailing her compensation package at Grab. |
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab in the year 2013. Tan Hooi Ling's narrative focuses on her educational background and career trajectory leading up to her role at Grab, without detailing her compensation. |
# ============== 1 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|----------------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab         | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013 | Not Available          | Not Available         | Not Available | Not Available                    | Tan Hooi Ling co-founded Grab in Kuala Lumpur after identifying an opportunity to make taking taxis safer. The idea was conceived during her time at Harvard Business School and further developed into a business plan that was a runner-up in a contest held by HBS. This achievement provided them with access to external resources and advisors. Initially launched as MyTeksi, the name was later changed to Grab to give it a more regional appeal. Tan Hooi Ling took a six-month leave from McKinsey to launch Grab, indicating her deep involvement from the start. |
# ```
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013.0 | Not Available | Not Available | Not Available | Not Available | The text provides an overview of Tan Hooi Ling's journey with Grab, highlighting the rapid growth and expansion of the company since its inception. It touches on the challenges faced, such as competition with Uber and regulatory hurdles, as well as the importance of adaptation and practical implementation of ideas. However, it does not disclose specific income details such as salary, bonuses, shares, or other benefits received by Tan Hooi Ling during her tenure in 2013. |
# ============== 1 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2013.0 | Not Available | Not Available | Not Available | Not Available | The text does not provide specific details about Tan Hooi Ling's income from her employment at Grab in 2013. It mentions her role and contributions to the company but does not disclose her salary, bonuses, shares, or other benefits. Tan Hooi Ling is portrayed as a key figure in Grab's development, focusing on creating a platform beneficial for all stakeholders, including drivers, passengers, and partners. However, her personal income details, including salary, shares, bonuses, and benefits from Grab, are not mentioned.
# ============== 1 ===============
# ...
#
# This table reflects the constraints of the provided text, which does not include specific income-related information for Tan Hooi Ling for the year 2021 at Grab.
# ============== 9 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares                                                                 | Benefit received from Employment | Narrative                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|------------------------------------------------------------------------|----------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2021 | Not Available          | Not Available         | 2,598,192,720 Class A Ordinary Shares; 2,867,235 Class A Ordinary Shares | Not Available                    | Tan Hooi Ling, serving in multiple leadership roles at Grab, including Co-founder and COO, was involved in significant share-related transactions in 2021. Specific details about salary, bonuses, and other benefits are not provided in the text. The shares mentioned are part of the compensation structure related to the Business Combination event, indicating a substantial equity stake in the company. However, exact figures for salary, bonuses, and other benefits remain undisclosed. |
# ```
# ============== 9 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares            | Benefit received from Employment | Narrative                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|-------------------|---------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2021 | Not Available          | Not Available         | 22,907,952 Class B | Not Available                    | Tan Hooi Ling, in her multifaceted roles at Grab for the year 2021, held a significant number of shares, specifically 22,907,952 Class B Ordinary Shares. Additionally, she had the potential to acquire 7,243,301 more Class B Ordinary Shares within 60 days upon the exercise of options or vesting of restricted share units awarded under Grab's share incentive plans. Salary, bonuses, and other benefits details are not provided in the text. |
# ```
# ============== 9 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2021.0 | Not Available | Not Available | Yes | Not Available | Tan Hooi Ling, as a key executive at Grab, was involved in a deed extending the lock-up period for shares initially set to expire on May 30, 2022, to May 30, 2023. This indicates Tan Hooi Ling held shares in Grab during 2021, but specific details regarding salary, bonuses, and other benefits are not provided in the text. |
# ============== 9 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|----------------------------------|--------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2021 | Not Available           | Not Available          | Not Available | Not Available                         | The text does not provide specific details about Tan Hooi Ling's income from Grab in 2021. It mentions Tan Hooi Ling's involvement with the National University of Singapore and her position on the Board of Trustees, but no information regarding salary, shares, bonuses, or other benefits from Grab is disclosed. Tan Hooi Ling no longer held any position at Grab since December 31, 2023. |
# ```
# ============== 9 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                                                                                                                                                                                                                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|----------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2021 | Not Available          | Not Available         | Not Available | Not Available                        | The text does not provide specific details about Tan Hooi Ling's salary, bonuses, shares, or other benefits received from Grab for the year 2021. It mentions Tan Hooi Ling's involvement with Grab and a transition related to shareholding in Jaya Grocer, indicating a significant role within the company but does not detail income specifics from the employment at Grab. |
# ```
# ============== 10 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income from her employment at Grab for the year 2022. It mentions her role as co-founder and chief operating officer but does not detail her salary, bonuses, shares, or other benefits received during that time. |
# ============== 10 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|-----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling, serving in multiple operational and technology leadership roles including Co-founder and COO at Grab, has been instrumental in the company's expansion and operations across 65 cities in seven countries. Despite Grab's significant growth and its valuation of over US$5 billion, specific details regarding Tan Hooi Ling's income, including salary, bonuses, shares, and other benefits for the year 2022, are not provided in the text. Tan Hooi Ling prefers to stay behind the scenes, focusing on the work and operational aspects of Grab, rather than seeking media attention. |
# ============== 10 ===============
# ```markdown
# | Employer Name | Location                                  | Job title                                                                 | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative                                                                                   |
# |---------------|-------------------------------------------|---------------------------------------------------------------------------|------|------------------------|-----------------------|--------|----------------------------------|-----------------------------------------------------------------------------------------------|
# | Grab          | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022 | Not Available           | Not Available          | Not Available | Not Available                      | The text provided does not contain specific information regarding Tan Hooi Ling's income from Grab in 2022. It focuses on her background, personality, and work ethic without detailing her salary, bonuses, shares, or other benefits received during her tenure. |
# ```
# ============== 10 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, bonuses, shares, or other benefits received from her employment at Grab in the year 2022. It focuses on her personal background and her conversation with Sumiko, without delving into the specifics of her compensation package at Grab. Therefore, we cannot provide detailed information on her income from Grab for the specified year. |
# ============== 10 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, bonuses, shares, or other benefits received from her employment at Grab for the year 2022. It focuses on her educational background, early career decisions, and the beginning of her journey with Grab, without detailing her compensation package. |
# ============== 10 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022.0 | Not Available | Not Available | Not Available | Not Available | Tan Hooi Ling co-founded Grab and has played various operational and technology leadership roles within the company. Initially starting the company in Kuala Lumpur as MyTeksi, the name was later changed to Grab to give it a more regional appeal. Tan Hooi Ling took a six-month leave from McKinsey to help launch Grab, then returned to the company full-time in April 2015 after a stint at Salesforce. She oversees people operations and technology, indicating a significant role in the company's operations, although specific details about her income from Grab in 2022, including salary, bonuses, shares, and other benefits, are not provided in the text. |
# ============== 10 ===============
# | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment | Narrative |
# |---------------|----------|-----------|------|------------------------|-----------------------|--------|----------------------------------|-----------|
# | Grab | Kuala Lumpur, Malaysia & Regional/Singapore | Co-founder, COO, Chief Operating Officer, Technology Leader, various operational and technology leadership roles | 2022.0 | Not Available | Not Available | Not Available | Not Available | The text provided does not contain specific information regarding Tan Hooi Ling's income, including salary, bonuses, shares, or other benefits from her employment at Grab for the year 2022. The narrative focuses on her experiences and the growth of Grab, mentioning the challenges and achievements of the company, but does not detail her personal income or compensation. |

# %%
combined_text = "\n\n\n".join ([text for text in combined_result])

OPENAI_MODEL_GPT4_0125 = 'gpt-4-0125-preview'

llm = ChatOpenAI(model_name=OPENAI_MODEL_GPT4_0125 , temperature=0)

prompt_combine_result= rf"""
    You are summarising a set of result from LLM retrieval. The topic is the biography you like to write include {customer_name} early Employment 
    Each result of the LLM is separated by three blank lines (\n\n\n).
    The documents were originally formatted in Markdown.and structured in the following manner 
    
    <RESULT STRUCTURE> 
    # Summary of document
    Place the summary of the document here
    
    
    # Career 
    Output the career result in the following markdown format
    Put the output in markdown format as per the following table:
    | Employer Name | Location | Job title | Year | Salary from Employment | Bonus from Employment | Shares | Benefit received from Employment  | Narrative |

    Markdown table Data dictionary:
    Employer Name =  Employer name
    Location =  location employer is located at
    Job Title = Job title at place of employment 
    Year = Current Year under review
    Salary from employment  = Salary {customer_name} received for the year that {customer_name} was employed by employer
    Bonus from Employment = Bonus  {customer_name} received for the year that {customer_name} was employed by employer
    Shares = Shares  {customer_name} held in the company for the year
    Benefit from Employment = Benefits, other than Salary, Bonus and shares, receiverd by {customer_name} for the year that {customer_name} was employed by employer
    
    Sort the table by Employer Name

    The following contraints are only for Start Year and End Year Columns:
    - Start Year = Year of start of employment. Only output the year without month or day. Where Start Year is "Not Available" replace it with a 0. Where Start Year is "present" or "current", replace it with the current year
    - End Year = Year of end of employment. Only output the year without month or day. Where End Year is "Not Available" replace it with 0. Where End Year is "present" or "current", Replace it with the current year


    Task: 
    review the text between <RESULTS> and <\RESULTS>. 
    Combine the information into a single row where "Employer Name", "Location", "Job Title", and "Year" are the same 

    <RESULTS>
     {combined_text}
    <\RESULTS>

    contrainst:
        Ensure that # Summary of {customer_name} is comprehensive
        The output should retain the same structure in each section
        Do not review results that are "No information found!!"
        Do not include <RESULTS> or <\RESULTS> in the output
        Replace all "Not Available" with a 0
"""

result_employment_SOW = llm.invoke(prompt_combine_result)

print(result_employment_SOW.content)
# Out:
# ['interest, (ii) exercise veto rights with respect to certain reserved matters that fundamentally affect the business of the company, (iii) receive the economic benefits\n \nand absorb losses of the Philippine entities in proportion to the amount and value of our investment, and (b) an exclusive call option to purchase all or part of the\n \nequity interests in certain circumstances. In addition, the above-mentioned control-related rights under the Investment Agreement have been included in the\n \nAmended Articles of Incorporation and By-Laws of Grab PH Holdings Inc. The Amended Articles of Incorporation and By-Laws have been approved by the\n \nPhilippines SEC, the relevant terms of the Investment Agreement are memorialized in the Amended Articles of Incorporation and By-Laws which are public\n \nrecords that are binding not only on Grab PH Holdings Inc. and the shareholders but also on third parties in relation to the matters covered thereby. A breach of\n \nthe Investment Agreement (including in respect of the above-mentioned control rights) would give rise to the right to bring a claim for breach of contract\n \nthereunder. Additionally, any action that contravenes the Amended Articles of Incorporation and By-Laws would be invalid and unenforceable and thereby be\n \nincrementally beneficial to the party seeking to enforce its terms.\n \n•\nIn Malaysia, we own 50% of the voting shares in Jaya Grocer outright. The balance of the voting shares are owned by our Malaysian local partner, Green Aurora\n \nSdn Bhd (“Malaysian local partner”), an entity owned by our co-founder, Hooi Ling Tan. Pursuant to a management agreement entered into by us through our\n \nwholly owned subsidiary, Jaya Grocer and the Malaysian local partner, to the extent permitted by local law, we generally have the ability or right to decide,\n \namong others, on business and financial strategies, including funding, and other strategy matters in relation to the business of Jaya Grocer, in the best interest of',
#  'results of our Philippine operating entities in our consolidated financial statements in accordance with IFRS. The non-controlling interest of the Philippine shareholder is\n \naccounted for in our consolidated financial statements.\n(5)\nMalaysia: \nIn Malaysia, we operate Jaya Grocer, a mass-premium supermarket chain in Malaysia, through Jaya Grocer Holdings Sdn. Bhd. We own 50% of the voting\n \nshares in Jaya Grocer outright. The balance of the voting shares are owned by our Malaysian local partner, Green Aurora Sdn Bhd (“Malaysian local partner”), an entity\n \nowned by our co-founder, Hooi Ling Tan. Pursuant to a management agreement entered into by us through our wholly owned subsidiary, Jaya Grocer and the Malaysian\n \nlocal partner, to the extent permitted by local law, we generally have the ability to right to decide, among others, on business and financial strategies, including funding,\n \nand other strategy matters in relation to the business of Jaya Grocer, in the best interest of Jaya Grocer and in consultation with the Malaysian local partner. Through\n \ncontractual rights with the Malaysian local partner together with certain other rights, we are able to consolidate the financial results of Jaya Grocer in our consolidated\n \nfinancial statements in accordance with IFRS.\n112',
#  'See “Item 4. Information on the Company—B. Business Overview—Our Approach” and “Item 4. Information on the Company—B. Business Overview—\nIntellectual Property” of this annual report.\nD.\nTrend Information\nNot applicable.\nE.\nCritical Accounting Estimates\nOur consolidated financial statements are prepared in accordance with IFRS. The preparation of these consolidated financial statements requires us to make\n \nestimates and assumptions that affect the reported amounts of assets, liabilities, revenue, expenses and related disclosures. See Notes 3.4, 4.1(i), 4.3, 4.9(v) and 4.11 to\n \nour consolidated financial statements included elsewhere in this report for additional information on our critical accounting estimates and policies.\nITEM 6. DIRECTORS, SENIOR MA\nNAGEMENT AND EMPLOYEES\n \nA.\nDirectors and Senior Management\nThe following table sets forth certain information relating to our executive officers and directors as of the date of this annual report. Our board of directors is\n \ncomprised of six directors.\n \n \n \n \n \n \nName\n  \nAge\n  \nPosition/Title\nAnthony Tan Ping Yeow\n  \n41\n  \nFounder, Chairman and Chief Executive Officer\nTan Hooi Ling\n  \n39\n  \nFounder and Director\nMaa Ming-Hokng\n  \n46\n  \nPresident\nAlex Hungate\n  \n56\n  \nChief Operating Officer\nPeter Oey\n  \n52\n  \nChief Financial Officer\nOng Chin Yin\n  \n48\n  \nChief People Officer\nSuthen Thomas Paradatheth\n  \n41\n  \nGroup Chief Technology Officer\nPhilipp Kandal\n \n40\n \nChief Product Officer\nJohn Rogers\n  \n54\n  \nIndependent Director\nDara Khosrowshahi\n  \n53\n  \nIndependent Director\nNg Shin Ein\n  \n48\n  \nIndependent Director\nOliver Jay\n  \n39\n  \nIndependent Director\n \nAnthony Tan Ping Yeow\n is our co-founder and has served as our Group Chief Executive Officer since our founding in 2012. Mr. Tan was named among\n \nFortune’s 40 under 40 in 2016 and 2018, The Bloomberg 50 in 2017, Fast Company’s 100 Most Creative People in 2018 and Fortune’s World’s 50 Greatest Leaders list',
#  'Table of Contents\n \nTan Hooi Ling\n is our co-founder and, following her graduation from Harvard Business School in mid-2011 through the end of 2011, helped build and run our\n \nteam in connection with the incorporation and launching of our business. Ms. Tan returned to our company in April 2015 and served as our Chief Operating Officer until\n \nJanuary 2022, overseeing critical pillars of our operations, including corporate strategy, technology (product, design, engineering, data science and analytics), user\n \nexperience and people operations. Before that, Ms. Tan led high priority strategic and operational projections at Salesforce from February 2013 to March 2015,\n \nspecializing in corporate strategy, corporate operations, pricing intelligence and monetization. She was also previously a consultant at McKinsey & Company from\n \nJanuary 2012 to January 2013 as an Associate, and from October 2006 to June 2009 as a Business Analyst, advising global corporations in Southeast Asia, North\n \nAmerica, Latin America and Australia on corporate strategy and operations. Ms. Tan sits on the board of Wise (formerly TransferWise). She received an MBA from\n \nHarvard Business School in 2011 and a bachelor of engineering (mechanical) degree from the University of Bath in 2006.\nMaa Ming-Hokng\n has served as our Group President since September 2016, and is responsible for corporate development activities, including strategic\n \npartnerships and investment opportunities, managing our overall capital structure, and other corporate activities. Prior to joining us, Mr. Maa was responsible for\n \nInvestments and M&A at Softbank from July 2014 to September 2016, where he helped oversee SoftBank’s investments in leading companies in the ride-sharing and e-\ncommerce industries, including Softbank’s April 2015 Series D investment in Grab and additional Series F investment in September 2016. From June 2012 to June 2014,',
#  'As of February 28, 2023, there were a total of 57,552,629 Ordinary Shares underlying grants of outstanding options, RSUs and restricted shares that were held\n \nby the executive officers and directors as a group, which included the following:\n•\nAnthony Tan Ping Yeow had (x) outstanding options to purchase a total of 12,130,207 Class B Ordinary Shares, with per-share exercise price of $1.90, grant\n \ndate of December 31, 2019, and expiration date of December 31, 2029, (y) outstanding restricted shares with respect to a total of 11,295,170 of Class B Ordinary\n \nShares with a grant date of April 11, 2021 and (z) outstanding RSUs with respect to a total of 6,621,176 of Class B Ordinary Shares with a grant date of March\n \n15, 2022;\n•\nTan Hooi Ling, who owned less than 1% of the outstanding Ordinary Shares, had (x) outstanding options to purchase Class B Ordinary Shares, with a per-share\n \nexercise price of $1.90, grant dates that range from December 24, 2019 to December 31, 2019, and expiration dates that range from December 24, 2029 to\n \nDecember 31, 2029, (y) outstanding restricted shares with respect to Class B Ordinary Shares with a grant date of April 11, 2021 and (z) outstanding RSUs with\n \nrespect to Class B Ordinary Shares with a grant date of March 15, 2022;\n145',
#  'Table of Contents\n \nITEM 7. MAJOR SHAREHO\nLDERS AND RELATED PARTY TRANSACTIONS\n \nA.\nMajor Shareholders\nThe following table sets forth information regarding the beneficial ownership of Ordinary Shares as of February 28, 2023 by:\n•\neach person known by us to be the beneficial owner of more than 5% of Ordinary Shares;\n•\neach of our directors and executive officers; and\n•\nall our directors and executive officers as a group.\nBeneficial ownership is determined in accordance with the rules of the SEC and includes voting or investment power with respect to, or the power to receive the\n \neconomic benefit of ownership of, the securities. In computing the number of shares beneficially owned by a person and the percentage ownership of that person, shares\n \nthat the person has the right to acquire within 60 days are included, including through the exercise of any option or other right or the conversion of any other security.\n \nHowever, these shares are not included in the computation of the percentage ownership of any other person. Each Class A Ordinary Share carries one vote, and each\n \nClass B Ordinary Share carries 45 votes.\nThe percentage of our Ordinary Shares beneficially owned is computed on the basis of 3,747,115,325 Class A Ordinary Shares and 120,327,102 Class B\n \nOrdinary Shares issued and outstanding as of February 28, 2023, and does not include the 25,999,981 Class A Ordinary Shares issuable upon the Warrants outstanding\n \nas of February 28, 2023.\n   \n \n   \n \nClass A\nOrdinary\nShares\n \nClass B\nOrdinary\nShares\n \n% of\nTotal\nOrdinary\nShares\n \n% of\nVoting\nPower(2)\n \nDirectors and Executive Officers\n \n  \n \n  \n \n \n \n \n \n \n \nAnthony Tan Ping Yeow\n   \n \n*\n \n   142,372,630\n  \n \n3.8%\n  \n \n 63.2%\n \n \nTan Hooi Ling\n   \n \n*\n \n     29,723,020\n  \n \n*\n   \n \n*\n \nMing-Hokng Maa\n   \n \n*\n \n     20,179,835\n  \n \n*\n   \n \n*\n \nAlex Hungate\n   \n \n*\n \n—\n \n*\n     \n \n*\n \nPeter Oey\n   \n \n*\n \n—\n \n*\n   \n \n*\n \n \nOng Chin Yin\n   \n \n*\n \n—\n \n*\n   \n \n*\n \n \nSuthen Thomas Paradatheth\n \n*\n \n—\n \n*\n   \n \n*',
#  'Table of Contents\n \nGHI Voting, Support and Lock-Up Agreements\nConcurrently with the execution of the Business Combination Agreement, the Company, AGC, GHI and certain of the shareholders of GHI entered into voting\n \nsupport and lock-up agreements (the “GHI Shareholder Support Agreements”), pursuant to which certain shareholders who hold an aggregate of at least 67% of the\n \noutstanding GHI voting shares (on an as converted basis) agreed, among other things: (a) to appear for purposes of constituting a quorum at any meeting of the\n \nshareholders of GHI called to seek approval of the transactions contemplated in the Business Combination Agreement and the other transaction proposals, (b) to vote in\n \nfavor of the transactions contemplated by the Business Combination Agreement and other transaction proposals, (c) to vote against any proposals that would materially\n \nimpede the transactions contemplated by the Business Combination Agreement or any other transaction proposal, (d) to not sell or transfer any of their shares.\nOn March 14, 2022, our key executives, namely, Anthony Tan, Hooi Ling Tan, Ming Maa, Peter Oey, Chin Yin Ong and Alex Hungate, entered into a deed in\n \nfavor of GHL to extend the term of the lock-up with respect to their respective shares for which the lock-up was initially scheduled to expire on May 30, 2022 in the\n \nvoting support and lock-up agreement and deed No. 1 dated April 12, 2021. In the case of Mr. Hungate, who joined us after the execution of the initial lock-up, the new\n \nlock-up will apply to any shares that vest prior to the new extension date. The extended lock-up, which is due to expire on May 30, 2023, is on substantially the same\n \nterms as the lock-up that was due to expire on May 30, 2022.\nFor further details regarding Ordinary Shares subject to the lock-up, see “Item 3. Key Information—D. Risk Factors—Risks Relating to the Company’s Securities',
#  'Table of Contents\n \nContract with National University of Singapore\nWe have a contract with the National University of Singapore’s NUS AI Lab for artificial intelligence research and intellectual property creation related to our\n \nbusiness for SGD 1.25 million (approximately $1 million) over two years from April 1, 2021. Our co-founder Tan Hooi Ling served on the Board of Trustees of the\n \nNational University of Singapore from June 2019 to March 2022.\nAmendment to Subscription Agreement with SVF Investments (UK) Limited\nWe are party to a subscription agreement dated March 6, 2019 (as amended, the “SVF Subscription Agreement”) with SVF Investments (UK) Limited (“SVF”), a\n \nprincipal shareholder, pursuant to which SVF agreed to purchase Series H Preference Shares of GHI (“Series H Shares”) for an aggregate purchase price of $2.0 billion\n \nat multiple closings. As of April 12, 2021, SVF had funded and closed on share purchases pursuant to the SVF Subscription Agreement in the aggregate amount of $1.8\n \nbillion, with a single closing remaining. On April 12, 2021, GHI and SVF amended the SVF Subscription Agreement to, among other things, reschedule the closing date\n \nfor the remaining $200 million funding to the third day following the date of the meeting of GHI’s shareholders at which GHI’s shareholders approve an increase of the\n \nauthorized number of certain GHI Shares under GHI’s memorandum and articles of association in connection with the purchase of such remaining shares, which\n \noccurred on November 26, 2021. On November 29, 2021, SVF consummated the purchase of 32,452,254 GHI Shares for $200 million.\nShareholding in Jaya Grocer\nIn January 2022 we completed the acquisition of a majority economic interest in Jaya Grocer. Our supermarkets business is subject to the Guidelines on Foreign\n \nParticipation in Distributive Trade Services (revised on May 12, 2020) issued by the Malaysian Ministry of Domestic Trade and Consumer Affairs, which stipulate a',
#  'maximum foreign voting cap of 50% for smaller retail formats (non-superstores) in Malaysia. Accordingly, 50% of the ordinary shares in Jaya Grocer are held by an\n \nentity (“Malaysian local partner”) owned by a Malaysian national, our co-founder Hooi Ling Tan. The full purchase of the ordinary shares in Jaya Grocer by the\n \nMalaysian local partner was funded through the purchase of preference shares in the Malaysian local partner by us. We, through a wholly owned subsidiary, have\n \nentered into a management agreement with Jaya Grocer and the Malaysian local partner that generally entitles us to decide, among others, on business and financial\n \nstrategies, including funding, and other strategy matters in relation to the business of Jaya Grocer, in the best interest of Jaya Grocer and in consultation with the\n \nMalaysian local partner.\nContract with MCars Sdn. Bhd.\nOn October 25, 2022, one of our wholly-owned subsidiaries, Green Rentals Sdn. Bhd., awarded a contract to purchase 400 units of Perodua Bezza, which were\n \ndue to be written off, to MCars. Sdn. Bhd. for MYR 11.4 million (approximately $3 million). This was conducted through a competitive bidding exercise considering\n \nthe best price and the ability to fulfill payment as per bidding document. Initially, it was awarded to another company that was the highest bidder, but the company was\n \nnot able to fulfill payment as per the bidding document. As a result, it was awarded to the next highest bidder, MCars. Sdn. Bhd. MCars Sdn. Bhd. is a wholly-owned\n \nsubsidiary of Orion SPV Pte. Ltd., a company 49%-owned by Ideal Team Enterprises Limited, which is in turn owned by Nicholas Tan, Mr. Tan’s brother.\nC.\nInterests of Experts and Counsel\nNot applicable.\n157',
#  'Table of Contents\n \n“\nGrabMart\n” and “\nGrabSupermarket\n” means our goods ordering and delivery booking services, which enables merchant-partners to accept bookings for goods\n \nfrom consumers (with options for on-demand deliveries, scheduled deliveries and pick-up orders) through our merchant-partner application, and it also enables\n \ndriver-partners to accept bookings for goods delivery services through our driver-partner application;\n“\nGrabMerchant\n” refers to the platform that we provide which equips merchant-partners with tools to grow their business;\n“\nGrabPay\n” means our digital payments solution, which allows consumers to make online and offline electronic payments using their mobile wallet and also\n \nallows our driver- and merchant-partners to receive digital payments for their services;\n“\nGrabRentals\n” refers to our offering which facilitates vehicle rental for our driver-partners at competitive rates through our rental fleet or third-party rental\n \nservices, to allow driver-partners with limited vehicle access to offer services on our platform;\n“\nGrabRewards\n” means our loyalty platform providing consumers that use services offered through our platform with a large catalog of points redemption\n \noptions, including offers from both popular merchant-partners and us;\n“\nJaya Grocer\n” refers to Jaya Grocer Holdings Sdn. Bhd., a mass-premium supermarket chain in Malaysia, in which we acquired a majority economic interest in\n \nJanuary 2022;\n“\nJustGrab\n” refers to our ride-hailing booking service, which enables driver-partners to accept bookings for private hire car rides or taxi rides, in both cases with\n \nupfront non-metered pricing;\n“\nKe\ny\n Executives\n” refers to our CEO and co-founder Anthony Tan, co-founder Tan Hooi Ling and President Maa Ming-Hokng;\n \n“\nMAS\n” means the Monetary Authority of Singapore;\n“\nmerchant-\np\nartner',
#  'increase the number of shares eligible for resale in the public market. Sales of substantial numbers of such shares in the public market or the fact that such warrants may\n \nbe exercised could adversely affect the market price of our Class A Ordinary Shares.\nFuture resales of our Ordinary Shares issued to our shareholders and other significant shareholders may cause the market price of our Class A Ordinary Shares\n \nand Warrants to drop significantly, even if our business is doing well.\nPursuant to our Shareholder Support Agreements and Sponsor Support Agreement, certain of our shareholders were or are restricted, subject to certain\n \nexceptions, from selling certain of our securities that they received as a result of the share exchange. As certain restrictions have recently expired or will expire,\n \nadditional securities have become or will be eligible for resale as follows:\n•\nOn May 30, 2022, which was 180 days after the consummation of the Business Combination, up to 2,598,192,720 Class A Ordinary Shares held by certain of\n \nour shareholders became eligible for resale, but pursuant to a new lock-up agreement dated March 14, 2022, lock-up restriction on certain of such Class A\n \nOrdinary Shares that are held by our key executives, namely, Anthony Tan, Hooi Ling Tan, Ming Maa, Peter Oey, Chin Yin Ong and Alex Hungate, was\n \nextended to May 30, 2023;\n•\nOne year after the consummation of the Business Combination, up to 2,867,235 Class A Ordinary Shares received by certain of our executives upon settlement\n \nof certain RSU awards granted with respect to the Business Combination;\n•\nThree years after the consummation of the Business Combination, up to 32,451,891 Ordinary Shares received by the Key Executives upon settlement of certain\n \nrestricted stock awards granted with respect to the Business Combination; and\n•\nThree years after the consummation of the Business Combination, up to 12,275,000 Class A Ordinary Shares, or other securities convertible into or exercisable']
